# %%
import pandas as pd

df = pd.read_csv("../dist_results_maxvals.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    t0  t1  t2  t3  t4              t_list               save_path device  \
# 0  10   0   0   0   0    [10, 0, 0, 0, 0]  ./dist_results_maxvals   cuda
# 1  50   0   0   0   0    [50, 0, 0, 0, 0]  ./dist_results_maxvals   cuda
# 2  15   0   0   0   0    [15, 0, 0, 0, 0]  ./dist_results_maxvals   cuda
# 3  15  25  10   0   0  [15, 25, 10, 0, 0]  ./dist_results_maxvals   cuda
# 4  25   0   0   0   0    [25, 0, 0, 0, 0]  ./dist_results_maxvals   cuda
#
#           exp_logs  test_size  ... Clean_loss  Attacked_loss Denoised_loss  \
# 0  experiment_logs        inf  ...   0.390518       2.342231      0.427041
# 1  experiment_logs        inf  ...   0.390518       2.342231      0.481053
# 2  experiment_logs        inf  ...   0.390518       2.342231      0.449109
# 3  experiment_logs        inf  ...   0.390518       2.342231      0.496502
# 4  experiment_logs        inf  ...   0.390518       2.342231      0.466072
#
#   Defended_loss Clean_acc  Attacked_acc  Denoised_acc  Defended_acc  \
# ...

# %%
df[(df["model"] == "pointnet") & (df["attack"] == "cw")].head()
# Out:
#      t0  t1  t2  t3  t4              t_list               save_path device  \
# 238  10   0   0   0   0    [10, 0, 0, 0, 0]  ./dist_results_maxvals   cuda
# 239  50   0   0   0   0    [50, 0, 0, 0, 0]  ./dist_results_maxvals   cuda
# 240  15   0   0   0   0    [15, 0, 0, 0, 0]  ./dist_results_maxvals   cuda
# 241  15  25  10   0   0  [15, 25, 10, 0, 0]  ./dist_results_maxvals   cuda
# 242  25   0   0   0   0    [25, 0, 0, 0, 0]  ./dist_results_maxvals   cuda
#
#             exp_logs  test_size           dataset  batch_size  scale_mode  \
# 238  experiment_logs        inf  modelnet40attack         256  shape_unit
# 239  experiment_logs        inf  modelnet40attack         256  shape_unit
# 240  experiment_logs        inf  modelnet40attack         256  shape_unit
# 241  experiment_logs        inf  modelnet40attack         256  shape_unit
# 242  experiment_logs        inf  modelnet40attack         256  shape_unit
#
# ...

# %%
models = ["pointnet", "pointnet2", "dgcnn", "pct", "pointmlp", "curvenet"]
for model in models:
    result = df[(df["model"] == model) & ((df["Attacked_acc"] > df["Clean_acc"]-0.05))]["attack"].unique()
    if len(result) != 0:
        print("Error model and attack:", model, *result)
# Out:
# Error model and attack: pointnet cw knn
# Error model and attack: pointnet2 cw knn
