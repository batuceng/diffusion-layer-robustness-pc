# %%
from dataset.modelnet40 import ModelNet40
from models.dgcnn import DGCNN_cls
from models.pointnet2 import PointNet2_cls

import torch
from torch.utils.data import DataLoader

from sklearn.metrics import accuracy_score

from attack.pgd import PGDLinf
from attack.vanila import VANILA

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = DGCNN_cls().to(device)
dataset = ModelNet40(num_points=1024, partition="test", scale_mode='unit_sphere')
dataloader = DataLoader(dataset=dataset, batch_size=32)
atk = PGDLinf(model=model, device=device, steps=30, eps=0.05, alpha=0.002)
# atk = VANILA(model=model, device=device, f=None)

atk_dgcnn_linf = atk.save(dataloader=dataloader)
# Out:
# batch 0/78
# batch 1/78
# batch 2/78
# batch 3/78
# batch 4/78
# batch 5/78
# batch 6/78
# batch 7/78
# batch 8/78
# batch 9/78
# batch 10/78
# batch 11/78
# batch 12/78
# batch 13/78
# batch 14/78
# batch 15/78
# batch 16/78
# batch 17/78
# batch 18/78
# batch 19/78
# batch 20/78
# batch 21/78
# batch 22/78
# batch 23/78
# batch 24/78
# batch 25/78
# batch 26/78
# batch 27/78
# batch 28/78
# batch 29/78
# batch 30/78
# batch 31/78
# batch 32/78
# batch 33/78
# batch 34/78
# batch 35/78
# batch 36/78
# batch 37/78
# batch 38/78
# batch 39/78
# batch 40/78
# batch 41/78
# batch 42/78
# batch 43/78
# batch 44/78
# batch 45/78
# batch 46/78
# batch 47/78
# batch 48/78
# batch 49/78
# batch 50/78
# batch 51/78
# batch 52/78
# batch 53/78
# batch 54/78
# batch 55/78
# batch 56/78
# batch 57/78
# batch 58/78
# batch 59/78
# batch 60/78
# batch 61/78
# batch 62/78
# batch 63/78
# batch 64/78
# batch 65/78
# batch 66/78
# batch 67/78
# batch 68/78
# batch 69/78
# batch 70/78
# batch 71/78
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib widget

fig = plt.figure()
ax = fig.add_subplot(projection="3d")

data_ind = 22
clean_pc = atk_dgcnn_linf[data_ind]["pointcloud"]
atk_pc = atk_dgcnn_linf[data_ind]["attacked"]

ax.scatter3D(clean_pc[:,0],clean_pc[:,1],clean_pc[:,2])
ax.scatter3D(atk_pc[:,0],atk_pc[:,1],atk_pc[:,2])

# %%
atk_dgcnn_linf[0].keys()

# %%
from dataset.modelnet40 import ModelNet40
from models.dgcnn import DGCNN_cls
from models.pointnet2 import PointNet2_cls

import torch
from torch.utils.data import DataLoader

from sklearn.metrics import accuracy_score

from attack.pgd import PGDLinf

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = PointNet2_cls().to(device)
dataset = ModelNet40(num_points=1024, partition="test", scale_mode='unit_sphere')
dataloader = DataLoader(dataset=dataset, batch_size=32)
atk = PGDLinf(model=model, device=device, steps=30, eps=0.05, alpha=0.002)

atk_pointnet_linf = atk.save(dataloader=dataloader)
# Out:
# --2023-08-04 19:22:48--  https://github.com/yanx27/Pointnet_Pointnet2_pytorch/raw/master/log/classification/pointnet2_ssg_wo_normals/checkpoints/best_model.pth
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/yanx27/Pointnet_Pointnet2_pytorch/master/log/classification/pointnet2_ssg_wo_normals/checkpoints/best_model.pth [following]
# --2023-08-04 19:22:49--  https://raw.githubusercontent.com/yanx27/Pointnet_Pointnet2_pytorch/master/log/classification/pointnet2_ssg_wo_normals/checkpoints/best_model.pth
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
from dataset.modelnet40 import ModelNet40
from models.dgcnn import DGCNN_cls
from models.pointnet2 import PointNet2_cls

import torch
from torch.utils.data import DataLoader

from sklearn.metrics import accuracy_score

from attack.pgdl2 import PGDL2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = DGCNN_cls().to(device)
dataset = ModelNet40(num_points=1024, partition="test", scale_mode='unit_sphere')
dataloader = DataLoader(dataset=dataset, batch_size=32)
atk = PGDL2(model=model, device=device, steps=30, eps=1.25, alpha=0.05)

atk_dgcnn_l2 = atk.save(dataloader=dataloader)
# Out:
# batch 0/78
# batch 1/78
# batch 2/78
# batch 3/78
# batch 4/78
# batch 5/78
# batch 6/78
# batch 7/78
# batch 8/78
# batch 9/78
# batch 10/78
# batch 11/78
# batch 12/78
# batch 13/78
# batch 14/78
# batch 15/78
# batch 16/78
# batch 17/78
# batch 18/78
# batch 19/78
# batch 20/78
# batch 21/78
# batch 22/78
# batch 23/78
# batch 24/78
# batch 25/78
# batch 26/78
# batch 27/78
# batch 28/78
# batch 29/78
# batch 30/78
# batch 31/78
# batch 32/78
# batch 33/78
# batch 34/78
# batch 35/78
# batch 36/78
# batch 37/78
# batch 38/78
# batch 39/78
# batch 40/78
# batch 41/78
# batch 42/78
# batch 43/78
# batch 44/78
# batch 45/78
# batch 46/78
# batch 47/78
# batch 48/78
# batch 49/78
# batch 50/78
# batch 51/78
# batch 52/78
# batch 53/78
# batch 54/78
# batch 55/78
# batch 56/78
# batch 57/78
# batch 58/78
# batch 59/78
# batch 60/78
# batch 61/78
# batch 62/78
# batch 63/78
# batch 64/78
# batch 65/78
# batch 66/78
# batch 67/78
# batch 68/78
# batch 69/78
# batch 70/78
# batch 71/78
# ...

# %%
from dataset.modelnet40 import ModelNet40
from models.dgcnn import DGCNN_cls
from models.pointnet2 import PointNet2_cls

import torch
from torch.utils.data import DataLoader

from sklearn.metrics import accuracy_score

from attack.pgd import PGDLinf

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = PointNet2_cls().to(device)
dataset = ModelNet40(num_points=1024, partition="test", scale_mode='unit_sphere')
dataloader = DataLoader(dataset=dataset, batch_size=32)
atk = PGDL2(model=model, device=device, steps=30, eps=1.25, alpha=0.05)

atk_pointnet_l2 = atk.save(dataloader=dataloader)
# Out:
# /home/robust/diffusion-point-cloud/pretrained/pointnet2_cls_weights/best_model.pth
# batch 0/78
# batch 1/78
# batch 2/78
# batch 3/78
# batch 4/78
# batch 5/78
# batch 6/78
# batch 7/78
# batch 8/78
# batch 9/78
# batch 10/78
# batch 11/78
# batch 12/78
# batch 13/78
# batch 14/78
# batch 15/78
# batch 16/78
# batch 17/78
# batch 18/78
# batch 19/78
# batch 20/78
# batch 21/78
# batch 22/78
# batch 23/78
# batch 24/78
# batch 25/78
# batch 26/78
# batch 27/78
# batch 28/78
# batch 29/78
# batch 30/78
# batch 31/78
# batch 32/78
# batch 33/78
# batch 34/78
# batch 35/78
# batch 36/78
# batch 37/78
# batch 38/78
# batch 39/78
# batch 40/78
# batch 41/78
# batch 42/78
# batch 43/78
# batch 44/78
# batch 45/78
# batch 46/78
# batch 47/78
# batch 48/78
# batch 49/78
# batch 50/78
# batch 51/78
# batch 52/78
# batch 53/78
# batch 54/78
# batch 55/78
# batch 56/78
# batch 57/78
# batch 58/78
# ---------------------------------------------------------------------------
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib widget

fig = plt.figure()
ax = fig.add_subplot(projection="3d")

data_ind = 37
clean_pc = atk_dgcnn_l2[data_ind]["pointcloud"]
atk_pc = atk_dgcnn_l2[data_ind]["attacked"]
ax.scatter3D(clean_pc[:,0],clean_pc[:,1],clean_pc[:,2])
ax.scatter3D(atk_pc[:,0],atk_pc[:,1],atk_pc[:,2])

# %%
import matplotlib.pyplot as plt
# %matplotlib widget

fig = plt.figure()
ax = fig.add_subplot(projection="3d")

data_ind = 37
clean_pc = atk_pointnet_l2[data_ind]["pointcloud"]
atk_pc = atk_pointnet_l2[data_ind]["attacked"]
ax.scatter3D(clean_pc[:,0],clean_pc[:,1],clean_pc[:,2])
ax.scatter3D(atk_pc[:,0],atk_pc[:,1],atk_pc[:,2])

# %%
s=torch.stack((atk_dgcnn_linf[0]["pointcloud"],atk_dgcnn_linf[1]["pointcloud"],atk_dgcnn_linf[2]["pointcloud"]))

# %%
delta = torch.empty_like(s).normal_()
d_flat = delta.view(s.size(0), -1)
n = d_flat.norm(p=2, dim=1).view(s.size(0),1,1)
r = torch.zeros_like(n).uniform_(0,1)

# %%
n

# %%
r

# %%
r/n*1.25

# %%
1.25*(r/n)
